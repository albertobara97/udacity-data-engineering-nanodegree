# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files("data/song_data")

#Show the first 10 song files
for i in range(10):
    print(song_files[i])
# Out:
# /home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json
# /home/workspace/data/song_data/A/A/A/TRAAAVG12903CFA543.json
# /home/workspace/data/song_data/A/A/A/TRAAARJ128F9320760.json
# /home/workspace/data/song_data/A/A/A/TRAAAPK128E0786D96.json
# /home/workspace/data/song_data/A/A/A/TRAAABD128F429CF47.json
# /home/workspace/data/song_data/A/A/A/TRAAAMO128F1481E7F.json
# /home/workspace/data/song_data/A/A/A/TRAAAMQ128F1460CD3.json
# /home/workspace/data/song_data/A/A/A/TRAAAVO128F93133D4.json
# /home/workspace/data/song_data/A/A/A/TRAAAEF128F4273421.json
# /home/workspace/data/song_data/A/A/A/TRAAAFD128F92F423A.json

# %%
filepath = song_files[0]

#Show filepath content
filepath
# Out:
# '/home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json'

# %%
df = pd.read_json(filepath, typ='series')
df
# Out:
# num_songs                            1
# artist_id           ARD7TVE1187B99BFB1
# artist_latitude                   None
# artist_longitude                  None
# artist_location        California - LA
# artist_name                     Casual
# song_id             SOMZWCG12A8C13C480
# title                 I Didn't Mean To
# duration                       218.932
# year                                 0
# dtype: object

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id', 'title', 'artist_id', 'year', 'duration']].values.tolist()
song_data
# Out:
# ['SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
#cur.execute("ROLLBACK;")
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].values.tolist()
artist_data
# Out:
# ['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
print(artist_data)
cur.execute(artist_table_insert, artist_data)
conn.commit()
# Out:
# ['ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None]

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files("data/log_data")
for i in range(10):
    print(log_files[i])
# Out:
# /home/workspace/data/log_data/2018/11/2018-11-30-events.json
# /home/workspace/data/log_data/2018/11/2018-11-11-events.json
# /home/workspace/data/log_data/2018/11/2018-11-23-events.json
# /home/workspace/data/log_data/2018/11/2018-11-24-events.json
# /home/workspace/data/log_data/2018/11/2018-11-25-events.json
# /home/workspace/data/log_data/2018/11/2018-11-20-events.json
# /home/workspace/data/log_data/2018/11/2018-11-15-events.json
# /home/workspace/data/log_data/2018/11/2018-11-01-events.json
# /home/workspace/data/log_data/2018/11/2018-11-03-events.json
# /home/workspace/data/log_data/2018/11/2018-11-13-events.json

# %%
filepath = log_files[0]
filepath
# Out:
# '/home/workspace/data/log_data/2018/11/2018-11-30-events.json'

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
print("Original size of df: ", df.shape)

df = df[df['page']=="NextSong"]


print("Original size of df: ", df.shape)
df.head()
# Out:
# Original size of df:  (388, 18)
# Original size of df:  (330, 18)
#           artist       auth firstName gender  itemInSession lastName  \
# 0  Stephen Lynch  Logged In    Jayden      M              0     Bell
# 1        Manowar  Logged In     Jacob      M              0    Klein
# 2      Morcheeba  Logged In     Jacob      M              1    Klein
# 3       Maroon 5  Logged In     Jacob      M              2    Klein
# 4          Train  Logged In     Jacob      M              3    Klein
#
#       length level                             location method      page  \
# 0  182.85669  free      Dallas-Fort Worth-Arlington, TX    PUT  NextSong
# 1  247.56200  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 2  257.41016  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 3  231.23546  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
# 4  216.76363  paid  Tampa-St. Petersburg-Clearwater, FL    PUT  NextSong
#
#    registration  sessionId                                  song  status  \
# 0  1.540992e+12        829                     Jim Henson's Dead     200
# 1  1.540558e+12       1049                           Shell Shock     200
# 2  1.540558e+12       1049  Women Lose Weight (Feat: Slick Rick)     200
# 3  1.540558e+12       1049             Won't Go Home Without You     200
# 4  1.540558e+12       1049                      Hey_ Soul Sister     200
#
#               ts                                          userAgent userId
# 0  1543537327796  Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...     91
# 1  1543540121796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 2  1543540368796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 3  1543540625796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73
# 4  1543540856796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     73

# %%
t = pd.to_datetime(df['ts'], unit='ms')
t.head()
# Out:
# 0   2018-11-30 00:22:07.796
# 1   2018-11-30 01:08:41.796
# 2   2018-11-30 01:12:48.796
# 3   2018-11-30 01:17:05.796
# 4   2018-11-30 01:20:56.796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = (t, t.dt.hour, t.dt.day, t.dt.week, t.dt.month, t.dt.year, t.dt.weekday)
#print(time_data)
column_labels = ('timestamp', 'hour', 'day', 'week_number', 'month', 'year', 'weekday')
print(column_labels)
# Out:
# ('timestamp', 'hour', 'day', 'week_number', 'month', 'year', 'weekday')

# %%
time_df = pd.DataFrame({column_labels[i]: time_data[i] for i in range(len(column_labels))})
time_df.head()
# Out:
#                 timestamp  hour  day  week_number  month  year  weekday
# 0 2018-11-30 00:22:07.796     0   30           48     11  2018        4
# 1 2018-11-30 01:08:41.796     1   30           48     11  2018        4
# 2 2018-11-30 01:12:48.796     1   30           48     11  2018        4
# 3 2018-11-30 01:17:05.796     1   30           48     11  2018        4
# 4 2018-11-30 01:20:56.796     1   30           48     11  2018        4

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_data = (df['userId'], df['firstName'], df['lastName'], df['gender'], df['level'])
user_headers = ('user_id', 'first_name', 'last_name', 'gender', 'level')
user_df = pd.DataFrame({user_headers[i]: user_data[i] for i in range(len(user_headers))})
user_df.head()
# Out:
#   user_id first_name last_name gender level
# 0      91     Jayden      Bell      M  free
# 1      73      Jacob     Klein      M  paid
# 2      73      Jacob     Klein      M  paid
# 3      73      Jacob     Klein      M  paid
# 4      73      Jacob     Klein      M  paid

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
#iterate over all dataframe rows
for index, row in df.iterrows():

    #if index is equal or greater than 5 then print values
    if(index <= 5):
        print("index\n----------------\n", index, "\n")
        print("row\n----------------\n", row, "\n")
    
    file_object = open('test_data.txt', 'a')
    file_object.write(','.join(str(v) for v in row))
    file_object.write("\n")
    print("file_obj\n----------------\n",','.join(str(v) for v in row),"\n")
    #file_object.write(row.str.cat(sep=','))
    
    #get songid and artistid from song and artist tables  
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    #if index is equal or greater than 5 then print values
    if(index <= 5):
        print("results\n----------------\n",results, "\n")
    
    #if results is not 
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (index, pd.to_datetime(row['ts'], unit='ms'), row['userId'], row['level'], songid, artistid, row['sessionId'], row['location'], row['userAgent'])
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
    file_object.close()
# Out:
# index
# ----------------
#  0
#
# row
# ----------------
#  artist                                               Stephen Lynch
# auth                                                     Logged In
# firstName                                                   Jayden
# gender                                                           M
# itemInSession                                                    0
# lastName                                                      Bell
# length                                                     182.857
# level                                                         free
# location                           Dallas-Fort Worth-Arlington, TX
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54099e+12
# sessionId                                                      829
# song                                             Jim Henson's Dead
# status                                                         200
# ts                                                   1543537327796
# userAgent        Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# userId                                                          91
# Name: 0, dtype: object
#
# file_obj
# ----------------
#  Stephen Lynch,Logged In,Jayden,M,0,Bell,182.85669,free,Dallas-Fort Worth-Arlington, TX,PUT,NextSong,1540991795796.0,829,Jim Henson's Dead,200,1543537327796,Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0),91
#
# results
# ----------------
#  None
#
# index
# ----------------
#  1
#
# row
# ----------------
#  artist                                                     Manowar
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                    0
# lastName                                                     Klein
# length                                                     247.562
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                     1049
# song                                                   Shell Shock
# status                                                         200
# ts                                                   1543540121796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 1, dtype: object
#
# file_obj
# ----------------
#  Manowar,Logged In,Jacob,M,0,Klein,247.562,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Shell Shock,200,1543540121796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# results
# ----------------
#  None
#
# index
# ----------------
#  2
#
# row
# ----------------
#  artist                                                   Morcheeba
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                    1
# lastName                                                     Klein
# length                                                      257.41
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                     1049
# song                          Women Lose Weight (Feat: Slick Rick)
# status                                                         200
# ts                                                   1543540368796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 2, dtype: object
#
# file_obj
# ----------------
#  Morcheeba,Logged In,Jacob,M,1,Klein,257.41016,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Women Lose Weight (Feat: Slick Rick),200,1543540368796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# results
# ----------------
#  None
#
# index
# ----------------
#  3
#
# row
# ----------------
#  artist                                                    Maroon 5
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                    2
# lastName                                                     Klein
# length                                                     231.235
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                     1049
# song                                     Won't Go Home Without You
# status                                                         200
# ts                                                   1543540625796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 3, dtype: object
#
# file_obj
# ----------------
#  Maroon 5,Logged In,Jacob,M,2,Klein,231.23546,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Won't Go Home Without You,200,1543540625796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# results
# ----------------
#  None
#
# index
# ----------------
#  4
#
# row
# ----------------
#  artist                                                       Train
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                    3
# lastName                                                     Klein
# length                                                     216.764
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                     1049
# song                                              Hey_ Soul Sister
# status                                                         200
# ts                                                   1543540856796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 4, dtype: object
#
# file_obj
# ----------------
#  Train,Logged In,Jacob,M,3,Klein,216.76363,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Hey_ Soul Sister,200,1543540856796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# results
# ----------------
#  None
#
# index
# ----------------
#  5
#
# row
# ----------------
#  artist                                                       LMFAO
# auth                                                     Logged In
# firstName                                                    Jacob
# gender                                                           M
# itemInSession                                                    4
# lastName                                                     Klein
# length                                                     227.996
# level                                                         paid
# location                       Tampa-St. Petersburg-Clearwater, FL
# method                                                         PUT
# page                                                      NextSong
# registration                                           1.54056e+12
# sessionId                                                     1049
# song                                            I'm In Miami Bitch
# status                                                         200
# ts                                                   1543541072796
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          73
# Name: 5, dtype: object
#
# file_obj
# ----------------
#  LMFAO,Logged In,Jacob,M,4,Klein,227.99628,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,I'm In Miami Bitch,200,1543541072796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# results
# ----------------
#  None
#
# file_obj
# ----------------
#  DJ Dizzy,Logged In,Jacob,M,5,Klein,221.1522,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Sexy Bitch,200,1543541299796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Fish Go Deep & Tracey K,Logged In,Jacob,M,6,Klein,377.41669,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,The Cure & The Cause (Dennis Ferrer Remix),200,1543541520796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  M83,Logged In,Jacob,M,7,Klein,96.1824,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Staring At Me,200,1543541897796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Saybia,Logged In,Jacob,M,8,Klein,257.25342,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,The Second You Sleep,200,1543541993796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Local Natives,Logged In,Jacob,M,9,Klein,266.05669,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Wide Eyes,200,1543542250796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  South Park,Logged In,Jacob,M,10,Klein,112.97914,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,La Resistance (Medley) (LP Version),200,1543542516796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  UNKLE Feat. Josh Homme,Logged In,Jacob,M,11,Klein,307.19955,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Restless,200,1543542628796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Justyna Steczkowska,Logged In,Jacob,M,12,Klein,333.53098,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Noc...,200,1543542935796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Evanescence,Logged In,Jacob,M,13,Klein,256.91383,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Like You,200,1543543268796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Coldplay,Logged In,Jacob,M,14,Klein,297.35138,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,God Put A Smile Upon Your Face,200,1543543524796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Hot Chip,Logged In,Jacob,M,15,Klein,333.50485,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Playboy,200,1543543821796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Ellie Goulding,Logged In,Jacob,M,16,Klein,205.06077,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Every Time You Go,200,1543544154796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Postal Service,Logged In,Jacob,M,17,Klein,307.53914,paid,Tampa-St. Petersburg-Clearwater, FL,PUT,NextSong,1540558108796.0,1049,Natural Anthem (Album),200,1543544359796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2",73
#
# file_obj
# ----------------
#  Jack Johnson,Logged In,Aiden,M,1,Hess,240.06485,free,La Crosse-Onalaska, WI-MN,PUT,NextSong,1540829025796.0,986,Taylor,200,1543547190796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36",86
#
# file_obj
# ----------------
#  Iron And Wine,Logged In,Aiden,M,2,Hess,153.05098,free,La Crosse-Onalaska, WI-MN,PUT,NextSong,1540829025796.0,986,Naked As We Can,200,1543547430796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36",86
#
# file_obj
# ----------------
#  The xx,Logged In,Aiden,M,3,Hess,158.24934,free,La Crosse-Onalaska, WI-MN,PUT,NextSong,1540829025796.0,986,Fantasy,200,1543547583796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36",86
#
# file_obj
# ----------------
#  The Antlers,Logged In,Aiden,M,4,Hess,328.88118,free,La Crosse-Onalaska, WI-MN,PUT,NextSong,1540829025796.0,986,Epilogue,200,1543547741796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36",86
#
# file_obj
# ----------------
#  Fattburger,Logged In,Aiden,M,5,Hess,217.20771,free,La Crosse-Onalaska, WI-MN,PUT,NextSong,1540829025796.0,986,Groovin',200,1543548069796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36",86
#
# file_obj
# ----------------
#  Chris Brown,Logged In,Layla,F,2,Griffin,203.80689,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Ain't No Way (You Won't Love Me),200,1543548563796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  Phoenix,Logged In,Layla,F,3,Griffin,278.07302,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Rome,200,1543548766796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  Jim Lauderdale/Ralph Stanley & The Clinch Mountain Boys,Logged In,Layla,F,5,Griffin,127.05914,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Highway Through My Home,200,1543549044796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  Musiq,Logged In,Layla,F,7,Griffin,297.84771,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,143,200,1543549171796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  Cass McCombs feat. Karen Black,Logged In,Layla,F,8,Griffin,322.06322,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Dreams-Come-True-Girl,200,1543549468796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  Scissor Sisters,Logged In,Layla,F,10,Griffin,352.522,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,I Don't Feel Like Dancin',200,1543549790796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  O.A.R.,Logged In,Layla,F,11,Griffin,315.74159,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Right On Time (Album Version),200,1543550142796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  1 Mile North,Logged In,Ryan,M,0,Smith,352.73098,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,Black Lines,200,1543550301796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  Muse,Logged In,Layla,F,12,Griffin,304.84853,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Uprising,200,1543550457796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  USS (Ubiquitous Synergy Seeker),Logged In,Ryan,M,1,Smith,307.61751,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,Man Makes The Zoo,200,1543550653796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  The Psychedelic Furs,Logged In,Layla,F,13,Griffin,417.07057,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Blacks/Radio,200,1543550761796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  EsmÃÂ©e Denters / Justin Timberlake,Logged In,Ryan,M,2,Smith,227.52608,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,Love Dealer (Featuring Justin Timberlake),200,1543550960796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  Alliance Ethnik,Logged In,Layla,F,14,Griffin,252.21179,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,ReprÃÂ©sente,200,1543551178796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  Train,Logged In,Ryan,M,3,Smith,216.76363,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,Hey_ Soul Sister,200,1543551187796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  Hoobastank,Logged In,Layla,F,15,Griffin,202.57914,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Up And Gone,200,1543551430796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  Ismael Serrano,Logged In,Layla,F,16,Griffin,179.35628,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,Te Conoci,200,1543551632796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  The Pussycat Dolls / Snoop Dogg,Logged In,Ryan,M,6,Smith,210.31138,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,Bottle Pop,200,1543551680796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  Dierks Bentley,Logged In,Layla,F,17,Griffin,198.63465,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,My Love Will Follow You,200,1543551811796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  59 Times the Pain,Logged In,Ryan,M,7,Smith,144.95302,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,Found Home,200,1543551890796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  Linkin Park,Logged In,Layla,F,18,Griffin,259.86567,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,My December,200,1543552009796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  New Order,Logged In,Ryan,M,8,Smith,288.05179,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,The Perfect Kiss,200,1543552034796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  Madeleine Peyroux,Logged In,Layla,F,19,Griffin,206.18404,paid,Lake Havasu City-Kingman, AZ,PUT,NextSong,1541057188796.0,1051,You're Gonna Make Me Lonesome When You Go,200,1543552268796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36",24
#
# file_obj
# ----------------
#  Bow Wow feat. Chris Brown and JohntÃÂ¡ Austin,Logged In,Ryan,M,9,Smith,268.06812,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,Shortie Like Mine,200,1543552322796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  Symphony X,Logged In,Ryan,M,10,Smith,389.45914,free,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1541016707796.0,1068,Domination,200,1543552590796,"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36",26
#
# file_obj
# ----------------
#  Minnie Riperton,Logged In,Chloe,F,0,Cuevas,238.73261,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Inside My Love (Digitally Remastered 93),200,1543552925796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Custom Blue,Logged In,Chloe,F,1,Cuevas,346.51383,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Structure,200,1543553163796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Rage Against The Machine,Logged In,Chloe,F,2,Cuevas,314.40934,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Killing In The Name,200,1543553509796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Milli Vanilli,Logged In,Katherine,F,0,Gay,197.92934,free,San Antonio-New Braunfels, TX,PUT,NextSong,1540968306796.0,1020,Girl You Know It's True,200,1543553771796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/534.59.10 (KHTML, like Gecko) Version/5.1.9 Safari/534.59.10",57
#
# file_obj
# ----------------
#  David Arkenstone,Logged In,Chloe,F,3,Cuevas,363.41506,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Waterfall (Spirit Of The Rainforest Album Version),200,1543553823796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Cosmo Vitelli,Logged In,Chloe,F,4,Cuevas,206.05342,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Robot Soul (Radio Edit),200,1543554186796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Morcheeba,Logged In,Chloe,F,5,Cuevas,277.4722,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Blindfold,200,1543554392796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Jason Mraz,Logged In,Chloe,F,6,Cuevas,243.48689,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,I'm Yours (Album Version),200,1543554669796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Deep Dish,Logged In,Avery,F,2,Watkins,274.28526,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Say Hello,200,1543554740796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Cutting Crew,Logged In,Chloe,F,7,Cuevas,263.07873,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,(I Just) Died In Your Arms,200,1543554912796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  The Velvet Underground,Logged In,Avery,F,3,Watkins,240.66567,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Sweet Jane,200,1543555014796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Future Rock,Logged In,Chloe,F,8,Cuevas,239.90812,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Gears,200,1543555175796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  The White Stripes,Logged In,Avery,F,4,Watkins,231.81016,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Seven Nation Army (Album Version),200,1543555254796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Coldplay,Logged In,Chloe,F,9,Cuevas,294.1122,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Fix You,200,1543555414796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Portishead,Logged In,Avery,F,5,Watkins,259.99628,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,It Could Be Sweet,200,1543555485796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Thelma Houston,Logged In,Chloe,F,10,Cuevas,196.51873,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,If This Was The Last Song,200,1543555708796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Chicane,Logged In,Avery,F,6,Watkins,223.92118,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Poppiholla,200,1543555744796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Metallica,Logged In,Ryann,F,1,Smith,466.54649,free,Palestine, TX,PUT,NextSong,1540685147796.0,1006,The Unforgiven III,200,1543555885796,Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0,92
#
# file_obj
# ----------------
#  Jennifer Lopez,Logged In,Chloe,F,11,Cuevas,301.34812,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Apresurate,200,1543555904796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Box Car Racer,Logged In,Avery,F,7,Watkins,196.93669,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,There Is,200,1543555967796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Robin Thicke,Logged In,Avery,F,8,Watkins,216.68526,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Would That Make U Love Me,200,1543556163796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Dashboard Confessional,Logged In,Chloe,F,12,Cuevas,226.29832,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Screaming Infidelities,200,1543556205796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Radney Foster,Logged In,Avery,F,9,Watkins,205.84444,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Big Idea,200,1543556379796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  La Roux,Logged In,Chloe,F,13,Cuevas,205.60934,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Bulletproof,200,1543556431796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Wax Tailor,Logged In,Avery,F,11,Watkins,177.68444,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,The Tune,200,1543556584796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Kings Of Leon,Logged In,Chloe,F,14,Cuevas,300.56444,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Trani,200,1543556636796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Kix,Logged In,Avery,F,12,Watkins,246.25587,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Girl Money,200,1543556761796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Mother Love Bone,Logged In,Chloe,F,15,Cuevas,495.72526,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Chloe Dancer/Crown Of Thorns,200,1543556936796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  The Decemberists,Logged In,Avery,F,13,Watkins,252.81261,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,The Bachelor and the Bride,200,1543557007796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Telefon Tel Aviv,Logged In,Avery,F,14,Watkins,222.09261,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,M,200,1543557259796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  B.o.B,Logged In,Chloe,F,16,Cuevas,269.63546,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Nothin' On You [feat. Bruno Mars] (Album Version),200,1543557431796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Amy Winehouse,Logged In,Avery,F,15,Watkins,409.96526,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,You Sent Me Flying / Cherry,200,1543557481796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  BEFORE THE DAWN,Logged In,Chloe,F,17,Cuevas,195.65669,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Faithless,200,1543557700796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  The Strokes,Logged In,Avery,F,16,Watkins,187.34975,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,You Only Live Once,200,1543557890796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Animals As Leaders,Logged In,Chloe,F,18,Cuevas,323.83955,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Tempting Time,200,1543557895796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Mazzy Star,Logged In,Avery,F,17,Watkins,297.9522,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Flowers In December,200,1543558077796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Cream,Logged In,Chloe,F,19,Cuevas,185.44281,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Take It Back,200,1543558218796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  MÃÂºm,Logged In,Avery,F,18,Watkins,68.67546,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Behind Two Hills&A Swimming Pool,200,1543558374796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  3OH!3,Logged In,Chloe,F,20,Cuevas,192.522,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,My First Kiss (Feat. Ke$ha) [Album Version],200,1543558403796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  N.W.A.,Logged In,Avery,F,19,Watkins,266.26567,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Straight Outta Compton (Extended Mix) (Edit) (Explicit),200,1543558442796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Dan Auerbach,Logged In,Chloe,F,21,Cuevas,296.95955,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Goin' Home,200,1543558595796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Lagwagon,Logged In,Avery,F,20,Watkins,173.322,paid,San Jose-Sunnyvale-Santa Clara, CA,PUT,NextSong,1540871783796.0,884,Sick,200,1543558708796,Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) Gecko/20100101 Firefox/31.0,30
#
# file_obj
# ----------------
#  Coldplay,Logged In,Chloe,F,22,Cuevas,294.1122,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Fix You,200,1543558891796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  John Mayer,Logged In,Chloe,F,23,Cuevas,250.38322,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Half Of My Heart,200,1543559185796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Kings Of Leon,Logged In,Chloe,F,24,Cuevas,201.79546,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Revelry,200,1543559435796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Ashbury Heights,Logged In,Chloe,F,25,Cuevas,198.60853,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,World Coming Down,200,1543559636796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Scooter,Logged In,Chloe,F,26,Cuevas,213.02812,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Fire,200,1543559834796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Boy Kill Boy,Logged In,Chloe,F,27,Cuevas,220.47302,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Shoot Me Down,200,1543560047796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Eric B. & Rakim,Logged In,Chloe,F,28,Cuevas,241.60608,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Juice (Know The Ledge),200,1543560267796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Josh Groban,Logged In,Chloe,F,29,Cuevas,243.40853,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Hymne A L'Amour (Album Version),200,1543560508796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Bad Religion,Logged In,Chloe,F,30,Cuevas,131.86567,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,We're Only Gonna Die (Album Version),200,1543560751796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Tempa T,Logged In,Chloe,F,31,Cuevas,236.35546,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Next Hype,200,1543560882796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Charttraxx Karaoke,Logged In,Chloe,F,32,Cuevas,225.17506,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Fireflies,200,1543561118796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Eagles,Logged In,Chloe,F,33,Cuevas,372.29669,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Hotel California,200,1543561343796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Eric Clapton,Logged In,Chloe,F,34,Cuevas,409.57342,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Little Wing,200,1543561715796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Spineshank,Logged In,Chloe,F,35,Cuevas,187.6371,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Smothered (Album Version),200,1543562124796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Kaiser Chiefs,Logged In,Chloe,F,36,Cuevas,221.07383,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Try Your Best,200,1543562311796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Dominique A,Logged In,Chloe,F,37,Cuevas,153.20771,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Le Courage Des Oiseaux,200,1543562532796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Kill Hannah,Logged In,Chloe,F,38,Cuevas,224.49587,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Lips Like Morphine (Album Version),200,1543562685796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  I:gor,Logged In,Chloe,F,39,Cuevas,190.27546,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Kiedys zrozumiesz,200,1543562909796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  The All-American Rejects,Logged In,Braden,M,0,Parker,206.96771,free,Youngstown-Warren-Boardman, OH-PA,PUT,NextSong,1540999292796.0,1082,Fallin' Apart,200,1543562949796,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",74
#
# file_obj
# ----------------
#  Guns N' Roses,Logged In,Chloe,F,40,Cuevas,284.05506,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Don't Cry (Original),200,1543563099796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  White Denim,Logged In,Chloe,F,41,Cuevas,148.55791,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Transparency,200,1543563383796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  El Canto del Loco,Logged In,Chloe,F,42,Cuevas,226.0371,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,La Suerte De Mi Vida,200,1543563531796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Grinderswitch,Logged In,Chloe,F,43,Cuevas,268.2771,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Redwing,200,1543563757796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Donovan,Logged In,Chloe,F,44,Cuevas,169.22077,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Starfish-On-The-Toast (2008 Digital Remaster),200,1543564025796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  As I Lay Dying,Logged In,Chloe,F,45,Cuevas,348.1073,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1079,Illusions,200,1543564194796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  matchbox twenty,Logged In,Mohammad,M,3,Rodriguez,241.34485,paid,Sacramento--Roseville--Arden-Arcade, CA,PUT,NextSong,1540511766796.0,1075,Bright Lights (Remastered Version),200,1543565771796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",88
#
# file_obj
# ----------------
#  Kinky,Logged In,Mohammad,M,4,Rodriguez,105.32526,paid,Sacramento--Roseville--Arden-Arcade, CA,PUT,NextSong,1540511766796.0,1075,Field Goal,200,1543566012796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",88
#
# file_obj
# ----------------
#  Shania Twain,Logged In,Mohammad,M,5,Rodriguez,250.51383,paid,Sacramento--Roseville--Arden-Arcade, CA,PUT,NextSong,1540511766796.0,1075,Nah!,200,1543566117796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",88
#
# file_obj
# ----------------
#  Hinder,Logged In,Mohammad,M,6,Rodriguez,231.73179,paid,Sacramento--Roseville--Arden-Arcade, CA,PUT,NextSong,1540511766796.0,1075,By The Way,200,1543566367796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",88
#
# file_obj
# ----------------
#  The Spencer Davis Group,Logged In,Mohammad,M,7,Rodriguez,165.27628,paid,Sacramento--Roseville--Arden-Arcade, CA,PUT,NextSong,1540511766796.0,1075,Keep On Running,200,1543566598796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",88
#
# file_obj
# ----------------
#  SOJA,Logged In,Mohammad,M,8,Rodriguez,355.89179,paid,Sacramento--Roseville--Arden-Arcade, CA,PUT,NextSong,1540511766796.0,1075,I Dont Wanna Wait,200,1543566763796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",88
#
# file_obj
# ----------------
#  Infected Mushroom,Logged In,Mohammad,M,9,Rodriguez,463.72526,paid,Sacramento--Roseville--Arden-Arcade, CA,PUT,NextSong,1540511766796.0,1075,Echonomix,200,1543567118796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",88
#
# file_obj
# ----------------
#  Unkle Bob,Logged In,Mohammad,M,10,Rodriguez,160.10404,paid,Sacramento--Roseville--Arden-Arcade, CA,PUT,NextSong,1540511766796.0,1075,One By One,200,1543567581796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",88
#
# file_obj
# ----------------
#  Alex Ubago,Logged In,Matthew,M,1,Jones,313.28608,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Sin Miedo a Nada (con Amaia Montero),200,1543572774796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  The Twilight Singers,Logged In,Matthew,M,2,Jones,286.53669,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Bonnie Brae,200,1543573087796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  Chikita Violenta,Logged In,Matthew,M,3,Jones,255.92118,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,War,200,1543573373796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  Cat Stevens,Logged In,Matthew,M,4,Jones,225.17506,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Sad Lisa,200,1543573628796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  Kenny Garrett,Logged In,Matthew,M,5,Jones,265.19465,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,The House That Nat Built (Album Version),200,1543573853796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  You Me At Six,Logged In,Matthew,M,6,Jones,216.68526,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Jealous Minds Think Alike,200,1543574118796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  Nellie Lutcher,Logged In,Matthew,M,7,Jones,195.70893,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,My Mother's Eyes,200,1543574334796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  Kid Cudi / Kanye West / Common,Logged In,Matthew,M,8,Jones,237.76608,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Make Her Say,200,1543574529796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  Tiro De Gracia,Logged In,Matthew,M,9,Jones,214.83057,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Viaje Sin Rumbo (2004 Digital Remaster),200,1543574766796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  polarkreis 18,Logged In,Matthew,M,10,Jones,265.29914,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Dreamdancer,200,1543574980796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  + / - {Plus/Minus},Logged In,Matthew,M,11,Jones,318.98077,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,The Queen of Nothing,200,1543575245796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  Dr Feelgood,Logged In,Ryann,F,0,Smith,216.13669,free,Palestine, TX,PUT,NextSong,1540685147796.0,1092,Riot In Cell Block Number Nine,200,1543575385796,Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0,92
#
# file_obj
# ----------------
#  Harmonia,Logged In,Matthew,M,12,Jones,655.77751,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Sehr kosmisch,200,1543575563796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
#  Chimaira,Logged In,Ryann,F,1,Smith,377.36444,free,Palestine, TX,PUT,NextSong,1540685147796.0,1092,Everything You Love (Album Version),200,1543575601796,Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0,92
#
# file_obj
# ----------------
#  Joshua Radin,Logged In,Ryann,F,2,Smith,211.27791,free,Palestine, TX,PUT,NextSong,1540685147796.0,1092,Someone Else's Life,200,1543575978796,Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0,92
#
# file_obj
# ----------------
#  Bajaga & Instruktori,Logged In,Ryann,F,3,Smith,254.95465,free,Palestine, TX,PUT,NextSong,1540685147796.0,1092,Godine prolaze,200,1543576189796,Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0,92
#
# file_obj
# ----------------
#  The Virgins,Logged In,Matthew,M,13,Jones,169.37751,paid,Janesville-Beloit, WI,PUT,NextSong,1541062818796.0,998,Private Affair (Amended Album Version),200,1543576218796,"Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36",36
#
# file_obj
# ----------------
# ...
#
# file_obj
# ----------------
#  Drop Dead_ Gorgeous,Logged In,Rylan,M,29,George,156.70812,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Dressed For Friend Requests (Album Version),200,1543596546796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Dwight Yoakam,Logged In,Rylan,M,30,George,239.3073,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,You're The One,200,1543596702796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Trouble,Logged In,Rylan,M,31,George,205.11302,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Tuesday's Child,200,1543596941796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  OneRepublic,Logged In,Rylan,M,33,George,237.97506,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,All The Right Moves,200,1543597146796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Switchblade Symphony,Logged In,Rylan,M,34,George,259.5522,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Wicked,200,1543597383796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Sharooz,Logged In,Rylan,M,35,George,234.05669,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,My Distressor 40Khz ReRub Mix,200,1543597642796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Explosions In The Sky,Logged In,Rylan,M,36,George,522.9971,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Six Days At The Bottom Of The Ocean,200,1543597876796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Emmylou Harris,Logged In,Chloe,F,1,Cuevas,194.63791,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Little Bird,200,1543598174796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Jack Johnson,Logged In,Chloe,F,2,Cuevas,153.67791,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,The Horizon Has Been Defeated,200,1543598368796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Radiohead,Logged In,Rylan,M,37,George,249.93914,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Everything In Its Right Place,200,1543598398796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Andrew Bird,Logged In,Chloe,F,3,Cuevas,215.87546,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Heretics,200,1543598521796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Metallica,Logged In,Rylan,M,38,George,380.21179,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Sabbra Cadabra,200,1543598647796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Lonnie Gordon,Logged In,Chloe,F,4,Cuevas,181.21098,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Catch You Baby (Steve Pitron & Max Sanna Radio Edit),200,1543598736796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Dropkick Murphys,Logged In,Chloe,F,5,Cuevas,167.73179,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Shattered,200,1543598917796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Eric B. & Rakim,Logged In,Rylan,M,39,George,240.32608,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,As The Rhyme Goes On,200,1543599027796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Dierks Bentley,Logged In,Chloe,F,6,Cuevas,223.242,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Settle For A Slowdown,200,1543599084796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Regina Spektor,Logged In,Rylan,M,40,George,290.14159,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Daniel Cowman,200,1543599267796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Angelspit,Logged In,Chloe,F,7,Cuevas,241.94567,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Make You Sin,200,1543599307796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Young Gunz / Beanie Sigel,Logged In,Chloe,F,8,Cuevas,292.44036,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Roc U,200,1543599548796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  DJ Dizzy,Logged In,Rylan,M,41,George,221.1522,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Sexy Bitch,200,1543599557796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Base Ball Bear,Logged In,Rylan,M,42,George,255.60771,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Sayonara-Nostalgia,200,1543599778796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Morcheeba,Logged In,Chloe,F,9,Cuevas,101.95546,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,In The Hands Of The Gods (Featuring Biz Markie),200,1543599840796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Bitter:Sweet,Logged In,Chloe,F,10,Cuevas,194.16771,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Don't Forget To Breathe,200,1543599941796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Basshunter Feat. DJ Mental Theos Bazzheadz,Logged In,Rylan,M,43,George,152.65914,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Now You're Gone,200,1543600033796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  BjÃÂ¶rk,Logged In,Chloe,F,11,Cuevas,348.57751,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Undo,200,1543600135796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Rihanna,Logged In,Rylan,M,44,George,239.75138,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,G4L,200,1543600185796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Evanescence,Logged In,Rylan,M,45,George,220.3424,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Hello,200,1543600424796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Mr. Vegas,Logged In,Chloe,F,12,Cuevas,240.69179,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Tamale,200,1543600483796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Mischa Daniels,Logged In,Rylan,M,46,George,419.81342,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Another Place,200,1543600644796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  The Menzingers,Logged In,Chloe,F,13,Cuevas,276.00934,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Straight To Hell,200,1543600723796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Justin Timberlake,Logged In,Chloe,F,14,Cuevas,288.93995,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Cry Me A River,200,1543600999796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Vilma Palma e Vampiros,Logged In,Rylan,M,47,George,338.18077,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Un Camino Hasta Vos,200,1543601063796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  CCCP - Fedeli Alla Linea,Logged In,Chloe,F,15,Cuevas,329.66485,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Sura (2008 Digital Remaster),200,1543601287796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Kid Cudi / MGMT / Ratatat,Logged In,Rylan,M,48,George,295.67955,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Pursuit Of Happiness (nightmare),200,1543601401796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Drake / Kanye West / Lil Wayne / Eminem,Logged In,Chloe,F,16,Cuevas,357.66812,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Forever,200,1543601616796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  A Day To Remember,Logged In,Rylan,M,49,George,247.64036,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Homesick [Acoustic],200,1543601696796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  T.I.,Logged In,Jayden,M,0,Bell,299.75465,free,Dallas-Fort Worth-Arlington, TX,PUT,NextSong,1540991795796.0,1085,Dead And Gone [feat. Justin Timberlake] (Explicit Album Version),200,1543601780796,Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0),91
#
# file_obj
# ----------------
#  The Offspring,Logged In,Rylan,M,50,George,163.3171,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,It'll Be a Long Time (Album Version),200,1543601943796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Jorge Gonzalez,Logged In,Chloe,F,17,Cuevas,272.14322,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Esta Es Para Hacerte FÃÂ©liz,200,1543601973796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Sneaker Pimps,Logged In,Jayden,M,1,Bell,260.91057,free,Dallas-Fort Worth-Arlington, TX,PUT,NextSong,1540991795796.0,1085,Spin Spin Sugar,200,1543602079796,Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0),91
#
# file_obj
# ----------------
#  Escape The Fate,Logged In,Rylan,M,51,George,266.73587,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,This War Is Ours (The Guillotine II),200,1543602106796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Juanes,Logged In,Chloe,F,18,Cuevas,243.27791,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,La Vida Es Un Ratico,200,1543602245796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  The Replacements,Logged In,Rylan,M,52,George,170.57914,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Never Mind,200,1543602372796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Sarah McLachlan,Logged In,Chloe,F,19,Cuevas,278.90893,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Possession,200,1543602488796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Sonny Boy Williamson,Logged In,Rylan,M,53,George,152.24118,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Don't Start Me Talkin',200,1543602542796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Soul II Soul Featuring Caron Wheeler,Logged In,Rylan,M,54,George,225.2273,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler),200,1543602694796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Florence + The Machine,Logged In,Chloe,F,20,Cuevas,219.66322,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Dog Days Are Over (Radio Edit),200,1543602766796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Pantera,Logged In,Rylan,M,55,George,286.69342,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Heresy  (LP Version),200,1543602919796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Cold,Logged In,Chloe,F,21,Cuevas,177.76281,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Remedy,200,1543602985796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Norther,Logged In,Chloe,F,22,Cuevas,246.54322,paid,San Francisco-Oakland-Hayward, CA,PUT,NextSong,1540940782796.0,1114,Frozen Angel,200,1543603162796,Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0,49
#
# file_obj
# ----------------
#  Foo Fighters,Logged In,Rylan,M,57,George,271.38567,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,The Pretender,200,1543603205796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Timbiriche,Logged In,Rylan,M,58,George,202.60526,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Besos De Ceniza,200,1543603476796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  A Perfect Circle,Logged In,Rylan,M,59,George,206.05342,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,Rose,200,1543603678796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Anberlin,Logged In,Rylan,M,60,George,348.682,paid,Birmingham-Hoover, AL,PUT,NextSong,1541020249796.0,1076,The Haunting,200,1543603884796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",16
#
# file_obj
# ----------------
#  Deas Vail,Logged In,Elijah,M,0,Davis,237.68771,free,Detroit-Warren-Dearborn, MI,PUT,NextSong,1540772343796.0,985,Anything You Say (Unreleased Version),200,1543607664796,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4",5

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
